# %%
import pickle
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
dt = pickle.load(open(os.path.join('dataset/data','train0.p'),'rb'))      # loading test data
X_test = dt['X_train']
Y_test = dt['Y_train']

# %%
plt.plot(X_test[0])
plt.show()

# %%
# loading metadata
dt = pickle.load(open(os.path.join('dataset/data','meta{}.p'.format(0)),'rb'))
max_ppg = dt['max_ppg']
min_ppg = dt['min_ppg']
max_abp = dt['max_abp']
min_abp = dt['min_abp']
print(max_ppg, min_ppg, max_abp, min_abp)
# Out:
# 2.556812316715545 -2.2496148582600237 199.98749589709124 50.0

# %%
length = 500
name = 'Unet_model1_fold0'

model = UnetLite1.build(length)

model.load_weights(os.path.join('ml/output/models',f'{name}.h5'))
Y_test_pred_approximate = model.predict(X_test,verbose=1)
# Out:
# 1522/1522 [==============================] - 73s 48ms/step

# %%
name2 = 'UnetL2_model2_fold0'
model2 = UnetLite2.build(length)

model2.load_weights(os.path.join('ml/output/models',f'{name2}.h5'))
Y_test_refinement = model.predict(Y_test_pred_approximate,verbose=1)
# Out:
# 1522/1522 [==============================] - 59s 39ms/step

# %%
plt.plot(Y_test[0], label="True output")
plt.plot(Y_test_refinement[0], label="Predict output")
plt.legend()
plt.show()

print(len(Y_test_pred_approximate[500][0]))
# Out:
# 1

# %%
plt.plot(X_test[2], label="True output")
plt.plot(Y_test[2], label="Predict output")
plt.legend()
plt.show()

# %%
import h5py, os
import matplotlib.pyplot as plt
import numpy as np
import pickle

length = 500
fl = h5py.File(os.path.join('dataset/data/', 'data.hdf5'), 'r')
ppg = fl['data'][0][0][:length]
abp = fl['data'][0][1][:length]

# print(ppg)

mean = sum(ppg)/len(ppg)
m_ppg = [x - mean for x in ppg]

m_ppg = np.array(m_ppg).reshape(length, 1)
# m_ppg2 = np.array(ppg).reshape(-1, 1)

# print(m_ppg[:2])
# print(m_ppg2[:2])
# plt.plot(ppg, label='ppg')
plt.plot(m_ppg, label='m_ppg')
# plt.legend()
plt.show()

# %%
ppg = pickle.load(open(os.path.join('dataset/ppgs','1.p'),'rb'))			# ppg signal
print(len(ppg))
# Out:
# 1000

# %%
l = map(str, list(range(500)) + ['SBP','DBP'])
x = [[]]*502
z = zip(l,x)
d = dict(z)

d['0'].append(2)
d['0'].append(2)

print(d)
# Out:
# {'0': [2, 2], '1': [2, 2], '2': [2, 2], '3': [2, 2], '4': [2, 2], '5': [2, 2], '6': [2, 2], '7': [2, 2], '8': [2, 2], '9': [2, 2], '10': [2, 2], '11': [2, 2], '12': [2, 2], '13': [2, 2], '14': [2, 2], '15': [2, 2], '16': [2, 2], '17': [2, 2], '18': [2, 2], '19': [2, 2], '20': [2, 2], '21': [2, 2], '22': [2, 2], '23': [2, 2], '24': [2, 2], '25': [2, 2], '26': [2, 2], '27': [2, 2], '28': [2, 2], '29': [2, 2], '30': [2, 2], '31': [2, 2], '32': [2, 2], '33': [2, 2], '34': [2, 2], '35': [2, 2], '36': [2, 2], '37': [2, 2], '38': [2, 2], '39': [2, 2], '40': [2, 2], '41': [2, 2], '42': [2, 2], '43': [2, 2], '44': [2, 2], '45': [2, 2], '46': [2, 2], '47': [2, 2], '48': [2, 2], '49': [2, 2], '50': [2, 2], '51': [2, 2], '52': [2, 2], '53': [2, 2], '54': [2, 2], '55': [2, 2], '56': [2, 2], '57': [2, 2], '58': [2, 2], '59': [2, 2], '60': [2, 2], '61': [2, 2], '62': [2, 2], '63': [2, 2], '64': [2, 2], '65': [2, 2], '66': [2, 2], '67': [2, 2], '68': [2, 2], '69': [2, 2], '70': [2, 2], '71': [2, 2],
# ...
